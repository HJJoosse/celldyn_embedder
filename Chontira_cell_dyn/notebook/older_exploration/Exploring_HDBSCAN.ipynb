# %% [markdown]
# ## Exploring HDBSCAN from https://github.com/christopherjenness/DBCV
# ## with their DBCV evaluation technique

# %%
from sklearn import datasets
import matplotlib.pyplot as plt
import seaborn as sns
import sys
sys.path.append("T:/laupodteam/AIOS/Chontira/CellDynClustering")
from evaluation.fast_dunn_index import dunn_fast
from scipy.spatial.distance import euclidean
from sklearn.metrics import davies_bouldin_score, silhouette_score

n_samples=150
noisy_moons = datasets.make_moons(n_samples=n_samples, noise=.05)
X = noisy_moons[0]
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
from sklearn.cluster import KMeans

kmeans =  KMeans(n_clusters=2)
kmeans_labels = kmeans.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=kmeans_labels)
plt.show()
# Out:
# C:\Users\cchumsae\Anaconda3\envs\CellDynCluster\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
import hdbscan

hdbscanner = hdbscan.HDBSCAN()
hdbscan_labels = hdbscanner.fit_predict(X)
plt.scatter(X[:,0], X[:,1], c=hdbscan_labels)

# %%
kmeans_score = DBCV(X, kmeans_labels, dist_function=euclidean)
hdbscan_score = DBCV(X, hdbscan_labels, dist_function=euclidean)


print(kmeans_score, hdbscan_score)
print(dunn_fast(X, hdbscan_labels))
print(davies_bouldin_score(X, hdbscan_labels))
# Out:
# -0.712615827247249 -0.7454873416245595
# 0.0015562764904573539
# 27.653787867042716

# %% [markdown]
# ### Not really clear. Looks like the results are wrong for DBVC from https://github.com/christopherjenness/DBC
